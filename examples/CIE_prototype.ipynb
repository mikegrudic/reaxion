# %% [markdown]
# # Collisional Ionization Equilibrium of H and He

# %% [markdown]
# Example of using `jaco` to solve for collisional ionization equilibrium (CIE) for a hydrogen-helium mixture and plot the ionization states as a function of temperature. This notebook contains various prototyped solvers to expose and experiment with the methods - see `jaco.Process.chemical_equilibrium` for the actual solver and `CIE.ipynb` for an example of how to use it.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import numpy as np
from matplotlib import pyplot as plt
import sympy as sp
from time import time

# %% [markdown]
# # Simple processes
# A simple process is defined by a single reaction, with a specified rate.
#
# Let's inspect the structure of a single process, the gas-phase recombination of H+: `H+ + e- -> H + hν`

# %%
from jaco.processes import CollisionalIonization, GasPhaseRecombination

process = GasPhaseRecombination("H+")
print(f"Name: {process.name}")
print(f"Heating rate coefficient: {process.heat_rate_coefficient}")
print(f"Heating rate per cm^-3: {process.heat}"),
print(f"Rate coefficient: {process.rate_coefficient}")
print(f"Recombination rate per cm^-3: {process.rate}")
print(f"RHS of e- number density equation: {process.network["e-"]}")
# Out:
# Name: Gas-phase recombination of H+
# Heating rate coefficient: -1.46719838641439e-26*sqrt(T)/((0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)
# Heating rate per cm^-3: -1.46719838641439e-26*sqrt(T)*n_H+*n_e-/((0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)
# Rate coefficient: 1.41621465870114e-10/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)
# Recombination rate per cm^-3: 1.41621465870114e-10*n_H+*n_e-/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)
# RHS of e- number density equation: -1.41621465870114e-10*n_H+*n_e-/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)

# %% [markdown]
# Note that all symbolic representations assume CGS units as is standard in ISM physics.

# %% [markdown]
# ## Composing processes
# Now let's define our full network as a sum of simple processes

# %%
processes = [CollisionalIonization(s) for s in ("H", "He", "He+")] + [GasPhaseRecombination(i) for i in ("H+", "He+", "He++")]
system = sum(processes)

system.subprocesses
# Out:
# [Collisional Ionization of H,
#  Collisional Ionization of He,
#  Collisional Ionization of He+,
#  Gas-phase recombination of H+,
#  Gas-phase recombination of He+,
#  Gas-phase recombination of He++]

# %% [markdown]
# Summed processes keep track of all subprocesses, e.g. the total net heating rate is:

# %%
system.heat
# Out:
# -1.55e-26*n_He+*n_e-/T**0.3647 - 1.2746917300104e-21*sqrt(T)*n_H*n_e-*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 1.46719838641439e-26*sqrt(T)*n_H+*n_e-/((0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252) - 9.37661057635428e-22*sqrt(T)*n_He*n_e-*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 4.9524176975855e-22*sqrt(T)*n_He+*n_e-*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 5.86879354565754e-26*sqrt(T)*n_He++*n_e-/((0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)

# %% [markdown]
# Summing processes also sums all chemical and gas/dust cooling/heating rates.

# %%
system.print_network_equations()
# Out:
# dn_H+/dt = 5.85e-11*sqrt(T)*n_H*n_e-*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 1.41621465870114e-10*n_H+*n_e-/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)
# dn_He+/dt = 2.38e-11*sqrt(T)*n_He*n_e-*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 5.68e-12*sqrt(T)*n_He+*n_e-*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - n_He+*n_e-*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)) + 5.66485863480458e-10*n_He++*n_e-/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252)
# dn_H/dt = -5.85e-11*sqrt(T)*n_H*n_e-*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 1.41621465870114e-10*n_H+*n_e-/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)
# dn_e-/dt = 5.85e-11*sqrt(T)*n_H*n_e-*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 2.38e-11*sqrt(T)*n_He*n_e-*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 5.68e-12*sqrt(T)*n_He+*n_e-*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - n_He+*n_e-*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)) - 1.41621465870114e-10*n_H+*n_e-/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252) - 5.66485863480458e-10*n_He++*n_e-/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252)
# dn_He++/dt = 5.68e-12*sqrt(T)*n_He+*n_e-*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 5.66485863480458e-10*n_He++*n_e-/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252)
# dn_He/dt = -2.38e-11*sqrt(T)*n_He*n_e-*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + n_He+*n_e-*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108))

# %% [markdown]
# ## Solving ionization equilibrium
#
# Today we would like to solve for ionization equilibrium given a temperature `T`. That means finding the chemical abundances that set this thing to 0:

# %%
system.network["e-"]
# Out:
# 5.85e-11*sqrt(T)*n_H*n_e-*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 2.38e-11*sqrt(T)*n_He*n_e-*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 5.68e-12*sqrt(T)*n_He+*n_e-*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - n_He+*n_e-*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)) - 1.41621465870114e-10*n_H+*n_e-/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252) - 5.66485863480458e-10*n_He++*n_e-/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252)

# %% [markdown]
# The full network above had 6 equations, but we may introduce two known quantities: the total H number density and the helium mass fraction Y.
#
# `n_Htot = n_H + n_H+`
#
# `n_He + n_He+ + n_He++ = Y/(4-Y) n_Htot`
#
# We may also invoke conservation of electrons:
#
# `n_e- = n_H+ + n_He+ + 2 n_He++`
#
# This allows us to eliminate 3 variables from the system.

# %%
Y = sp.symbols("Y")
nHtot = sp.symbols("n_Htot")

substitutions = {
                "n_e-": sp.symbols("n_H+") + sp.symbols("n_He+")  + 2*sp.symbols("n_He++"),
                "n_H+": nHtot - sp.symbols("n_H"),
                 "n_He++": Y/(4-4*Y) * nHtot - sp.symbols("n_He") - sp.symbols("n_He+"),                  
}

for species in system.network:
    for s in substitutions:
        system.network[species] = system.network[species].subs(s, substitutions[s])
        system.heat = system.heat.subs(s,substitutions[s])

system.network
# Out:
# defaultdict(int,
#             {'H+': 5.85e-11*sqrt(T)*n_H*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 1.41621465870114e-10*(-n_H + n_Htot)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252),
#              'He+': 2.38e-11*sqrt(T)*n_He*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 5.68e-12*sqrt(T)*n_He+*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108))*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot) + 5.66485863480458e-10*(Y*n_Htot/(4 - 4*Y) - n_He - n_He+)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252),
#              'H': -5.85e-11*sqrt(T)*n_H*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 1.41621465870114e-10*(-n_H + n_Htot)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252),
#              'e-': 5.85e-11*sqrt(T)*n_H*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 2.38e-11*sqrt(T)*n_He*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 5.68e-12*sqrt(T)*n_He+*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108))*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot) - 5.66485863480458e-10*(Y*n_Htot/(4 - 4*Y) - n_He - n_He+)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252) - 1.41621465870114e-10*(-n_H + n_Htot)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252),
#              'He++': 5.68e-12*sqrt(T)*n_He+*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 5.66485863480458e-10*(Y*n_Htot/(4 - 4*Y) - n_He - n_He+)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252),
#              'He': -2.38e-11*sqrt(T)*n_He*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108))*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)})

# %% [markdown]
# ### Symbolic Jacobian
# For our remaining unknowns we can define a Jacbon w.r.t. those quantities:

# %%
unknowns = sp.symbols("n_H n_He n_He+")
#unknowns = sp.symbols("n_H n_e-")
knowns = sp.symbols("T n_Htot Y")

jac = []
reduced_network = []
for species, rhs in system.network.items(): 
    if f"n_{species}" in substitutions: continue
    reduced_network.append(rhs)
    jac.append([sp.diff(rhs, u) for u in unknowns])

sp.Matrix(jac)
# Out:
# Matrix([
# [               -2.38e-11*sqrt(T)*n_He*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 5.68e-12*sqrt(T)*n_He+*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) + n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)) - 5.66485863480458e-10*(Y*n_Htot/(4 - 4*Y) - n_He - n_He+)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252), -4.76e-11*sqrt(T)*n_He*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 1.136e-11*sqrt(T)*n_He+*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 2.38e-11*sqrt(T)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 2*n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)) - 1.13297172696092e-9*(Y*n_Htot/(4 - 4*Y) - n_He - n_He+)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252) - 5.66485863480458e-10*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252), -2.38e-11*sqrt(T)*n_He*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 5.68e-12*sqrt(T)*n_He+*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 5.68e-12*sqrt(T)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) + n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)) - (0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108))*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot) - 5.66485863480458e-10*(Y*n_Htot/(4 - 4*Y) - n_He - n_He+)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252) - 5.66485863480458e-10*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252)],
# [5.85e-11*sqrt(T)*n_H*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 5.85e-11*sqrt(T)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 1.41621465870114e-10*(-n_H + n_Htot)/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252) - 1.41621465870114e-10*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252),                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          1.17e-10*sqrt(T)*n_H*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 2.83242931740229e-10*(-n_H + n_Htot)/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252),                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 5.85e-11*sqrt(T)*n_H*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 1.41621465870114e-10*(-n_H + n_Htot)/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252)],
# [                                                                                                                                                                                                                                             2.38e-11*sqrt(T)*n_He*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) - n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)),                                                                                                                                                                                                                                                                                                                                                                                                           4.76e-11*sqrt(T)*n_He*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 2.38e-11*sqrt(T)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 2*n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)),                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                2.38e-11*sqrt(T)*n_He*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) - n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108)) + (0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108))*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)]])

# %% [markdown]
# ## Numerical solution
#
# To solve the system numerically we may use Newton iterations:
#
# $$ \mathbf{X}_{n+1} = \mathbf{X}_{\rm n} - \mathbf{J}^{-1}\left(\mathbf{X}_{\rm n}\right) \mathbf{f(\mathbf{X}_{\rm n})}$$
#
# where $\mathbf{X}$ is the vector of unknowns, $\mathbf{f}(\mathbf{X})$ is the vector of RHS in the chemical rates we wish to solve = 0, and $J$ is the Jacobian of $f(X)$.

# %%
 #1e-6,1e-6,0.5) # n_H n_He n_He+ n_e- initial guess
print(reduced_network)
func = sp.lambdify(unknowns+knowns, reduced_network) # what is going on in the backend here?
jacfunc =  sp.lambdify(unknowns + knowns, jac)


def solve_abundances(Tval, x0=None):
    knownvals = (Tval, 1, 0.24)

    def f_numerical(X):
        arg = tuple(X) + knownvals
        return func(*arg)

    def jac_numerical(X):
        arg = tuple(X) + knownvals
        return jacfunc(*arg)

    if x0 is None:
        x0 = np.array([0.5,1e-5, 1e-5])

    X = np.copy(x0)
    X_iter = []
    dx = 1e100 * x0
    tol = 1e-6
    n_iter = 0
    while(np.any(np.abs(dx/X) > tol)):
#    for i in range(100):
        X_iter.append(np.copy(X))
        J = jac_numerical(X)
        f = f_numerical(X)
        try:
            dx = -np.linalg.solve(J, f) # don't actually have to invert!
        except:
            break
        X += dx
        n_iter += 1
#    print(n_iter)
    return X

Tgrid = np.logspace(3,6,10**3)

sol = []

def run_solution():
    x0 = solve_abundances(Tgrid[0])
    for T in Tgrid:
        x0 = solve_abundances(T,x0=x0/1.1)
        sol.append(np.copy(x0))

run_solution()
sol = np.array(sol)


# need to abstract this process of substituting the conservation equations...
Y = 0.24
nHtot = 1
nHepp = Y/(4-4*Y)*nHtot - sol[:,1] - sol[:,2] 
sol = np.c_[sol, nHepp]
nHp = nHtot - sol[:,0]
ne = 2*nHepp + nHp + sol[:,2]
sol = np.c_[sol[:,0],nHp,sol[:,1],sol[:,2], nHepp, ne]


plt.loglog(Tgrid, sol, label=("H", "H+", "He", "He+", "He++", "e-"))#,label=unknowns)
plt.ylim(1e-4,3)
plt.ylabel(r"$x_i$")
#plt.ylabel(r"$n_i\,\left(\rm cm^{-3}\right)$")
plt.xlabel(r"T (K)")
plt.legend()
# Out:
# [2.38e-11*sqrt(T)*n_He*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) - 5.68e-12*sqrt(T)*n_He+*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-631515/T)/(sqrt(10)*sqrt(T)/1000 + 1) - n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108))*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot) + 5.66485863480458e-10*(Y*n_Htot/(4 - 4*Y) - n_He - n_He+)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00059608348423851*sqrt(T) + 1.0)**1.748*(0.281807561832489*sqrt(T) + 1.0)**0.252), -5.85e-11*sqrt(T)*n_H*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-157809.1/T)/(sqrt(10)*sqrt(T)/1000 + 1) + 1.41621465870114e-10*(-n_H + n_Htot)*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)/(sqrt(T)*(0.00119216696847702*sqrt(T) + 1.0)**1.748*(0.563615123664978*sqrt(T) + 1.0)**0.252), -2.38e-11*sqrt(T)*n_He*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)*exp(-285335.4/T)/(sqrt(10)*sqrt(T)/1000 + 1) + n_He+*(0.0019*(1 + 0.3*exp(-94000.0/T))*exp(-470000.0/T)/T**1.5 + 1.93241606228058e-10/(sqrt(T)*(0.000164934781188511*sqrt(T) + 1.0)**1.7892*(4.84160744811772*sqrt(T) + 1.0)**0.2108))*(2*Y*n_Htot/(4 - 4*Y) - n_H - 2*n_He - n_He+ + n_Htot)]

# %%
import ChiantiPy.core as ch

he = ch.ioneq(2)
he.load()
he.calculate(Tgrid)

for i in range(3):
    plt.loglog(Tgrid, he.Ioneq[i], ls='dashed',color='black',label=("CHIANTI" if i==0 else None))
    plt.loglog(Tgrid, sol[:,2+i]/sol[:,2:5].sum(1), ls='solid',color='black',label=("jaco" if i==0 else None))
plt.ylim(1e-3,1.1)
plt.legend()
plt.xlabel(r"T (K)")
plt.ylabel(r"Fraction")
# Out:
#  ChiantiPy version 0.15.2
#  using cli
#  using CLI for selections
# <frozen genericpath>:39: RuntimeWarning: bool is used as a file descriptor
# /Users/mgrudic/Library/Python/3.13/lib/python/site-packages/ChiantiPy/core/IpyMspectrum.py:9: UserWarning: ipyparallel not found. You won't be able to use the ipymspectrum module
#   warnings.warn("ipyparallel not found. You won't be able to use the ipymspectrum module")
# Text(0, 0.5, 'Fraction')

# %% [markdown]
# # JAX implementation

# %%
 #1e-6,1e-6,0.5) # n_H n_He n_He+ n_e- initial guess
import jax, jax.numpy as jnp
from jaxopt import ScipyRootFinding


func = sp.lambdify(unknowns+knowns, reduced_network,modules='jax')
jacfunc =  sp.lambdify(unknowns + knowns, jac,modules='jax') # do we need this or should we diff on the jax side?


def solve_abundances(Tval, func=func, jacfunc=jacfunc, rtol=1e-2, atol=1e-100):

    def f_numerical(X,knownvals):
        return jnp.array(func(*X, *knownvals))

    if jacfunc is None:
        jac_numerical = jax.jacfwd(f_numerical)
    else:
        def jac_numerical(X,knownvals):
            return jnp.array(jacfunc(*X, *knownvals))

    x0 = jnp.array([0.5,1e-5, 1e-5])
    
    def solve_for_T(T):
        knownvals = jnp.array([T, 1, 0.24])

        def iter_condition(arg):
            X, dx = arg
            return jnp.any(jnp.abs(dx) > rtol * jnp.abs(X) + atol)

        def X_new(arg):
            X, _ = arg            
            dx = -jnp.linalg.solve(jac_numerical(X,knownvals),f_numerical(X,knownvals))
            return X + dx, dx # - jnp.linalg.solve(J,f)
        
        init_val = x0, 100*x0
        return jax.lax.while_loop(iter_condition, X_new, init_val)[0]

    X = jax.vmap(solve_for_T)(Tval)
    return X

Tgrid = np.logspace(3,6,10**6)
sol = solve_abundances(Tgrid)

# need to abstract this process of substituting the conservation equations...
Y = 0.24
nHtot = 1
nHepp = Y/(4-4*Y)*nHtot - sol[:,1] - sol[:,2] 
sol = np.c_[sol, nHepp]
nHp = nHtot - sol[:,0]
ne = 2*nHepp + nHp + sol[:,2]
sol = np.c_[sol[:,0],nHp,sol[:,1],sol[:,2], nHepp, ne]


plt.loglog(Tgrid, sol, label=("H", "H+", "He", "He+", "He++", "e-")) #,label=unknowns)
plt.ylim(1e-4,3)
plt.ylabel(r"$x_i$")
plt.xlabel(r"T (K)")
plt.legend()

#%timeit solve_abundances(Tgrid)

# %% [markdown]
# # Solving with JAX newton_rootsolve

# %%
params = np.c_[Tgrid, np.ones_like(Tgrid), 0.24*np.ones_like(Tgrid)]
guesses = np.array(len(Tgrid)*[[0.5,1e-5,1e-5]])
from jaco.numerics import newton_rootsolve

@jax.jit
def f_numerical(X, *params):
    return jnp.array(func(*X, *params))

sol = newton_rootsolve(f_numerical, guesses, params)

Y = 0.24
nHtot = 1
nHepp = Y/(4-4*Y)*nHtot - sol[:,1] - sol[:,2] 
sol_full = np.c_[sol, nHepp]
nHp = nHtot - sol[:,0]
ne = 2*nHepp + nHp + sol[:,2]
sol_full = np.c_[sol[:,0],nHp,sol[:,1],sol[:,2], nHepp, ne]


plt.loglog(Tgrid, sol_full, label=("H", "H+", "He", "He+", "He++", "e-")) #,label=unknowns)
plt.ylim(1e-4,3)
plt.ylabel(r"$x_i$")
plt.xlabel(r"T (K)")
plt.legend()

# %% [markdown]
# # Plotting the cooling rate

# %%
coolrate = sp.lambdify(("T",)+unknowns, system.heat.subs({"Y": Y, "n_Htot": 1}),modules='numpy')

plt.loglog(Tgrid, np.abs(coolrate(Tgrid, sol[:,0],sol[:,1],sol[:,2])),color='black'); plt.ylim(1e-28,1e-21); plt.xlabel("T (K)"); plt.ylabel(r"$\Lambda \,\left(\rm erg\,s^{-1}\,cm^{3}\right)$")
# Out:
# Text(0, 0.5, '$\\Lambda \\,\\left(\\rm erg\\,s^{-1}\\,cm^{3}\\right)$')
